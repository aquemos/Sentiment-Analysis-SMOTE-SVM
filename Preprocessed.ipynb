# %%
import re
import string
import nltk
nltk.download('punkt')
from nltk.tokenize import word_tokenize
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# True

# %%
import pandas as pd

# %%
df = pd.read_excel('Dataset.xlsx')
df
# Out:
#                                                Mentions Sentiment
# 0     Polsek Sungai Sampit melaksanakan pengamanan d...  Positive
# 1                            Dah ku kepak keja bruk blt  Positive
# 2     @Dennysiregar7 Kan sdh pada dapet BLT Bang Ã°Â...  Positive
# 3     Emak2 mulutnya kayak gini pasti miskin akhlak ...  Positive
# 4     Bhabinkamtibmas Polsek Banjar hadiri penyalura...  Positive
# ...                                                 ...       ...
# 2970  IBRIPKA M Nur Bhabinkamtibmas Ds Srimukti laks...  Positive
# 2971  @PelatihBaru @jokowi BLT bukan solusi Tapi kem...  Positive
# 2972  @jokowi Kebijakan pemerintah itu sering ruwet ...  Positive
# 2973  @msaid_didu Dana BLT Migor utk keluarga pra se...  Positive
# 2974  @ayah_gara @faithouse_ @ipank19124306 @TeddGus...  Negative
#
# [2975 rows x 2 columns]

# %%
def clean_tweet(text):
  # Mengubah teks ke lowercase
  text = text.lower()

  # Menghapus emoticon
  emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
  text = emoji_pattern.sub(r'', text)

  # Menghapus non ASCII character
  encoded_string = text.encode("ascii", "ignore")
  text = encoded_string.decode()

  # Menghapus tag, hastag, dan tanda baca
  text = ' '.join(re.sub("([@#_][A-Za-z0-9]+)|(\w+:\/\/\S+)|[0-9]|[@#_]|[\"#$%&'()*+,-./?!:;<=>@[\]^_`{|}~]","", text).split())
  
  return(text)

# %%
df["Mentions"] = df["Mentions"].apply(lambda x: clean_tweet(x))
df
# Out:
#                                                Mentions Sentiment
# 0     polsek sungai sampit melaksanakan pengamanan d...  Positive
# 1                            dah ku kepak keja bruk blt  Positive
# 2                           kan sdh pada dapet blt bang  Positive
# 3     emak mulutnya kayak gini pasti miskin akhlak d...  Positive
# 4     bhabinkamtibmas polsek banjar hadiri penyalura...  Positive
# ...                                                 ...       ...
# 2970  ibripka m nur bhabinkamtibmas ds srimukti laks...  Positive
# 2971  blt bukan solusi tapi kembalikan harga minyak ...  Positive
# 2972  kebijakan pemerintah itu sering ruwet dan ribe...  Positive
# 2973  dana blt migor utk keluarga pra sejahtera suda...  Positive
# 2974  biasanya begitu ngedumel pake fake facts tp kl...  Negative
#
# [2975 rows x 2 columns]

# %%
df.to_excel('Dataset preprocessed.xlsx', index=False)
